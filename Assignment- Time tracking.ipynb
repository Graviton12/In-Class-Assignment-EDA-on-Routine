# %% [markdown]
# # Programming Project 1 analysis using EDA tools
# - Name: Samia Mahmood
# - Date: 10/3/23
# - Version:

# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# ### Load the dataset and save it to a dataframe named 'df'
# ![image.png](attachment:image.png)

# %%
# loading data frame
df=pd.read_csv('Individual Project 1.csv')

# %%
# viewing data frame
df.head()
# Out:
#        Date Course_ID  Time (m)  \
# 0  9/5/2023    DS_160        80
# 1  9/6/2023  ECON_111        50
# 2  9/6/2023  PHYS_307        60
# 3  9/6/2023  MATH_216       100
# 4  9/6/2023  HIST_116        80
#
#                                              Summary
# 0  Today I worked on excel to analyze data while ...
# 1  Today I worked on understanding what price flo...
# 2  Today I worked on deriving the relativistic ki...
# 3  Today I used the software Maple to create 3D g...
# 4  Today I studied about the Italian Renaissance ...

# %% [markdown]
# ### Investigate your dataset

# %%
# checking statistics of data frame
df.describe()
# Out:
#          Time (m)
# count   87.000000
# mean    85.632184
# std     39.721447
# min     20.000000
# 25%     60.000000
# 50%     80.000000
# 75%    100.000000
# max    240.000000

# %%
# looking at a sample of 6 random rows from the data frame
df.sample(6)
# Out:
#          Date Course_ID  Time (m)  \
# 26  9/14/2023  PHYS_307       240
# 7    9/8/2023  ECON_111        80
# 42  9/20/2023  ECON_111        50
# 70  9/28/2023  MATH_216       120
# 61  9/25/2023  HIST_116        80
# 75  9/29/2023  MATH_216       100
#
#                                               Summary
# 26  Today I worked on practice problems which cove...
# 7   Today I worked on my online Cengage homework a...
# 42  Today I took notes on chapter 21 and finished ...
# 70                        Today I worked on homework.
# 61         Today I took a quiz over content material.
# 75    Today I learned more about partial derivatives.

# %%
# checking the columns and the data type for each
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       87 non-null     object
#  1   Course_ID  87 non-null     object
#  2   Time (m)   87 non-null     int64
#  3   Summary    87 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.8+ KB

# %% [markdown]
# ### Summary Statistics
# Calculate basic statistics for the 'Time (minutes)' column, such as mean, median, minimum, and maximum. This will give you an overview of how time is distributed across activities. use table and graphical representations
# ![image.png](attachment:image.png)

# %%
from datetime import datetime

# %%
df['Time (m)'].describe()
# Out:
# count     87.000000
# mean      85.632184
# std       39.721447
# min       20.000000
# 25%       60.000000
# 50%       80.000000
# 75%      100.000000
# max      240.000000
# Name: Time (m), dtype: float64

# %%
sns.boxplot(x='Course_ID', y='Time (m)', data=df)
# Out:
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Course_ID', ylabel='Time (m)'>

# %% [markdown]
# The boxplot shows that MATH 216 has many outliers while HIST 116 has a few outliers. Other courses such as PHYS 307 and DA 160 have no outliers and ECON 111 has only one outlier.

# %% [markdown]
# ### Create two new columns "day" and "day_name" using the "Date" column in which the day will represent the range of days
# ![image.png](attachment:image.png)

# %%
df['Date']=pd.to_datetime(df['Date'])
df['day_name']=df['Date'].dt.day_name()
df['day']=range(1, len(df) + 1)
df.head()
# Out:
#         Date Course_ID  Time (m)  \
# 0 2023-09-05    DS_160        80
# 1 2023-09-06  ECON_111        50
# 2 2023-09-06  PHYS_307        60
# 3 2023-09-06  MATH_216       100
# 4 2023-09-06  HIST_116        80
#
#                                              Summary   day_name  day
# 0  Today I worked on excel to analyze data while ...    Tuesday    1
# 1  Today I worked on understanding what price flo...  Wednesday    2
# 2  Today I worked on deriving the relativistic ki...  Wednesday    3
# 3  Today I used the software Maple to create 3D g...  Wednesday    4
# 4  Today I studied about the Italian Renaissance ...  Wednesday    5

# %%
# checking to see if columns were added and data type was converted
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       87 non-null     datetime64[ns]
#  1   Course_ID  87 non-null     object
#  2   Time (m)   87 non-null     int64
#  3   Summary    87 non-null     object
#  4   day_name   87 non-null     object
#  5   day        87 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 4.2+ KB

# %% [markdown]
# ### Data Visualization:
# 1. Create a histogram or bar chart to visually represent the distribution of time spent.
# 2. Create a  bar chart to visually represent the distribution of time spent on different courses and comment on the course you spent most and least time
# ![image-3.png](attachment:image-3.png)

# %%
sns.histplot(x='Time (m)', data=df)
# Out:
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Time (m)', ylabel='Count'>

# %% [markdown]
# The histogram shows that the ditribution of my time spent was right skewed.

# %%
sns.barplot(x='Course_ID', y='Time (m)', data=df, ci=False)
# Out:
# C:\Users\smahmood\AppData\Local\Temp\ipykernel_7016\3633880851.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='Course_ID', y='Time (m)', data=df, ci=False)
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Based on the bar graph, I spent the most amount of time time in MATH 216 (calculus III) and I spent the least amount of time in DS 160 (Intro the Data Science).

# %% [markdown]
# ### Activity Counts:
#
# Count the occurrences of each course in the dataset to see how often you engaged in each.

# %%
sns.histplot(x='Course_ID', data=df)
# Out:
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Course_ID', ylabel='Count'>

# %%
df['Course_ID'].value_counts()
# Out:
# Course_ID
# PHYS_307    23
# MATH_216    21
# ECON_111    19
# DS_160      12
# HIST_116    12
# Name: count, dtype: int64

# %% [markdown]
# Based of the histogram and data from value_counts(), I was most engaged with my PHYS 207 (Modern Physics) course.

# %% [markdown]
# ### Time Trends:
#
# Plot a line chart to visualize how time spent on activities changes over the observed days.
# ![image.png](attachment:image.png)

# %%
sns.lineplot(x='day', y='Time (m)', data=df, hue='Course_ID')
# Out:
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# The line graph shows how the time spent on activities changed throughout the days.

# %% [markdown]
# ### Course Analysis:
#
# For each course ex.(DS 160, CS 150, CS 440), calculate the total time spent. Which course received the most time, and which received the least?
# - Sample print statement: Total time spent on CS160: 180 min

# %%
df.groupby('Course_ID')['Time (m)'].sum().reset_index()
# Out:
#   Course_ID  Time (m)
# 0    DS_160       860
# 1  ECON_111      1485
# 2  HIST_116       940
# 3  MATH_216      2105
# 4  PHYS_307      2060

# %% [markdown]
# The course that received the most time was MATH 216 and the course that recieved the least amount of time is DS 160.

# %% [markdown]
# ### Correlations:
# - Examine whether there are any correlations between the day and the time spent. For example, do you spend more time on courses over days or less.
# ![image.png](attachment:image.png)

# %%
heat_map=df[['day', 'Time (m)']].corr()
cols=['day', 'Time (m)']
sns.heatmap(heat_map, xticklabels=cols, yticklabels=cols, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Based on the heat map, there is not much correlation between day and time spent. The day and the time spent are independent of one another.

# %% [markdown]
# ### Reflection on Findings
# Overall, based on the data, I spent the most amount of time with MATH 216 and the least od DS 160. This was evident from the bar graph for time spent and the courses. I was the most engaged with PHYS 307. This can be referenced from the histogram of the courses and by using value_counts(). In terms of basic statistics regarding time spent and the courses, the box plot shows that MATH 216 has many outliers. The histogram for the time spent was right skewed and the describe() method showed that the average time I spent was about 85 minutes. Additionally, the heat map showed there is no correlation between the day and time spent.
